# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# **Read the dataset**

# %%
train_data=pd.read_csv('train.csv')
train_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
test_data=pd.read_csv('test.csv')
test_data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %% [markdown]
# **EDA**

# %%
train_data.shape
# Out:
# (2000, 21)

# %%
test_data.shape
# Out:
# (1000, 21)

# %%
train_data.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
#Checking the columns
train_data.columns.tolist()
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
test_data.columns.tolist()
# Out:
# ['id',
#  'battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi']

# %%
train_data['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
#Information
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
#  18  three_g        1000 non-null   int64
#  19  touch_screen   1000 non-null   int64
#  20  wifi           1000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 164.2 KB

# %%
#countplot of target column
sns.countplot(x='price_range', data=train_data)
plt.show()

# %%
train_data['price_range']. unique()
# Out:
# array([1, 2, 3, 0])

# %%
#CountPlot for various columns
for i in train_data:
    if(train_data[i].nunique()<30):
        sns.countplot(x=train_data[i])
        plt.show()

# %%
 plt.subplots(figsize=(20,20))
 sns.heatmap(train_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
train_data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
#Distplot for various columns
plt.figure(figsize = (30,10))
plt.subplot(331)
sns.histplot(train_data['battery_power'])
plt.subplot(332)
sns.histplot(train_data['clock_speed'])
plt.subplot(333)
sns.histplot(train_data['int_memory'])
plt.subplot(334)
sns.histplot(train_data['m_dep'])
plt.subplot(335)
sns.histplot(train_data['mobile_wt'])
plt.subplot(336)
sns.histplot(train_data['px_height'])
plt.subplot(337)
sns.histplot(train_data['px_width'])
plt.subplot(338)
sns.histplot(train_data['ram'])
plt.subplot(339)
sns.histplot(train_data['talk_time'])
plt.show()

# %%
#bluetooth devices
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px
train_data["is_bluetooth"]=''
for i in range(len(train_data)):
    if train_data['blue'][i]==0:
        train_data['is_bluetooth'][i]='No'
    else:
        train_data['is_bluetooth'][i]='Yes'
px.pie(data_frame = train_data, names = 'is_bluetooth', title = 'Percentage of devices having bluetooth', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9aa0dcc5-e786-465e-b795-d153e9584c25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9aa0dcc5-e786-465e-b795-d153e9584c25")) {                    Plotly.newPlot(                        "9aa0dcc5-e786-465e-b795-d153e9584c25",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"is_bluetooth=%{label}<extra></extra>","labels":["No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","No","No","No","Yes","Yes","Yes","No","No","No","No","No","Yes","No","No","No","No","No","No","No","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","No","No","No","No","No","No","Yes","No","No","No","No","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No ...

# %%
#dual sim
train_data["is_DualSim"]=''
for i in range(len(train_data)):
    if train_data['dual_sim'][i]==0:
        train_data['is_DualSim'][i]='No'
    else:
        train_data['is_DualSim'][i]='Yes'
px.pie(data_frame = train_data, names = 'is_DualSim', title = 'Percentage of devices having dual sim', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1a7a9120-e693-46f6-a650-45ac7c86600a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a7a9120-e693-46f6-a650-45ac7c86600a")) {                    Plotly.newPlot(                        "1a7a9120-e693-46f6-a650-45ac7c86600a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"is_DualSim=%{label}<extra></extra>","labels":["No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","No","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","No","Yes","No","No","No","No","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","No","No","No","No","No","No","Yes","No","No","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","Yes","Yes", ...

# %%
#4G
train_data["is_4G"]=''
for i in range(len(train_data)):
    if train_data['four_g'][i]==0:
        train_data['is_4G'][i]='No'
    else:
        train_data['is_4G'][i]='Yes'
px.pie(data_frame = train_data, names = 'is_4G', title = 'Percentage of devices having 4G connection', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0ecf44c4-cb59-4951-8895-7ec0e3a45577" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ecf44c4-cb59-4951-8895-7ec0e3a45577")) {                    Plotly.newPlot(                        "0ecf44c4-cb59-4951-8895-7ec0e3a45577",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"is_4G=%{label}<extra></extra>","labels":["No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","No","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","No","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes ...

# %%
#3G
train_data["is_3G"]=''
for i in range(len(train_data)):
    if train_data['three_g'][i]==0:
        train_data['is_3G'][i]='No'
    else:
        train_data['is_3G'][i]='Yes'
px.pie(data_frame = train_data, names = 'is_3G', title = 'Percentage of devices having 3G connection', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="be92e7e9-032a-4b47-b400-cb90f1f9b016" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be92e7e9-032a-4b47-b400-cb90f1f9b016")) {                    Plotly.newPlot(                        "be92e7e9-032a-4b47-b400-cb90f1f9b016",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"is_3G=%{label}<extra></extra>","labels":["No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Y ...

# %%
#Touch Screen
train_data["is_touchscreen"]=''
for i in range(len(train_data)):
    if train_data['touch_screen'][i]==0:
        train_data['is_touchscreen'][i]='No'
    else:
        train_data['is_touchscreen'][i]='Yes'
px.pie(data_frame = train_data, names = 'is_touchscreen', title = 'Percentage of devices having touch screen', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a717753d-d261-428e-abfb-4e3f23e7beac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a717753d-d261-428e-abfb-4e3f23e7beac")) {                    Plotly.newPlot(                        "a717753d-d261-428e-abfb-4e3f23e7beac",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"is_touchscreen=%{label}<extra></extra>","labels":["No","Yes","Yes","No","Yes","No","No","Yes","No","No","No","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","No","No","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","No","No","No","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","No","No","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","No","No","No","No","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","No","No","Yes","Yes","Yes","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","No","No","No","No","No","No","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","Yes","No","No","No" ...

# %%
#Wifi
train_data["is_wifi"]=''
for i in range(len(train_data)):
    if train_data['wifi'][i]==0:
        train_data['is_wifi'][i]='No'
    else:
        train_data['is_wifi'][i]='Yes'
px.pie(data_frame = train_data, names = 'is_wifi', title = 'Percentage of devices having Wifi', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7392cd36-cd85-4ec9-a258-f2eb696ec8eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7392cd36-cd85-4ec9-a258-f2eb696ec8eb")) {                    Plotly.newPlot(                        "7392cd36-cd85-4ec9-a258-f2eb696ec8eb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"is_wifi=%{label}<extra></extra>","labels":["Yes","No","No","No","No","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","No","No","Yes","No","No","Yes","No","No","No","No","Yes","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","No", ...

# %%
#Processors
train_data["cores"]=''
for i in range(len(train_data)):
    if train_data['n_cores'][i]==1:
        train_data['cores'][i]='single core'
    elif train_data['n_cores'][i]==2:
        train_data['cores'][i]='dual core'
    elif train_data['n_cores'][i]==3:
        train_data['cores'][i]='triple core'
    elif train_data['n_cores'][i]==4:
        train_data['cores'][i]='quad core'
    elif train_data['n_cores'][i]==5:
        train_data['cores'][i]='penta core'
    elif train_data['n_cores'][i]==6:
        train_data['cores'][i]='hexa core'
    elif train_data['n_cores'][i]==7:
        train_data['cores'][i]='hepta core'
    else:
        train_data['cores'][i]='octa core'
px.pie(data_frame = train_data, names = 'cores', title = 'Percentage of devices having different types of cores', hole= 0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4ff55661-e6b5-4072-b48c-6fea884e5963" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ff55661-e6b5-4072-b48c-6fea884e5963")) {                    Plotly.newPlot(                        "4ff55661-e6b5-4072-b48c-6fea884e5963",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"cores=%{label}<extra></extra>","labels":["dual core","triple core","penta core","hexa core","dual core","single core","octa core","quad core","hepta core","penta core","penta core","octa core","quad core","quad core","single core","dual core","octa core","triple core","penta core","quad core","hepta core","dual core","quad core","triple core","triple core","octa core","quad core","hepta core","dual core","penta core","hepta core","octa core","single core","quad core","octa core","octa core","quad core","dual core","hexa core","dual core","single core","dual core","dual core","triple core","dual core","triple core","octa core","hepta core","octa core","octa core","triple core","octa core","dual core","triple core","hepta core","triple core","octa core","triple core","hexa core","penta core","triple core","octa core","dual core","dual core","triple core","triple core","quad core","triple core","dual core","quad core","hepta core","quad core","triple core","single core","quad core","hexa core","triple core","single core","quad core","hexa core","hepta core","quad core","penta core","triple core","single core","octa core","penta core","triple core","penta core","quad core","triple core","hepta core","hepta core","hexa core","triple core","triple core","penta core","hexa core","dual core","hepta core","hexa core","octa core","penta core","quad core","hepta core","quad core","penta core","penta core","single core","single core","triple core","hepta core","hexa core","penta core","hepta core","hepta core","octa core","triple core","single core","triple core","octa core","quad core","triple core","dual core","penta core","single core","quad core","hexa core","triple core","hexa core","hepta core","single core","hepta core","octa core","quad core","penta core","hexa core","octa core","hepta core","octa core","single core","triple core","single core","hepta core","triple core","dual core","dual core","hepta core","triple core","single core","penta core","hepta core","hexa core","dual core","dual core","single core","quad core","hexa core","hexa core","single core","penta core","hexa core","penta core","single core","octa core","quad core","octa core","hexa core","hepta core","quad core","hepta core","penta core","quad core","penta core","penta core","hexa core","hepta core","penta core","dual core","hepta core","single core","hexa core","octa core","quad core","penta core","triple core","hexa core","single core","single core","penta core","single core","penta core","octa core","dual core","quad core","hepta core","triple core","triple core","quad core","triple core","single core","hepta core","triple core","hepta core","hexa core","octa core","hexa core","penta core","hepta core","hexa core","triple core","octa core","penta core","penta core","single core","triple core","octa core","penta core","triple core","penta core","penta core","dual core","quad core","hexa core","quad core","dual core","single core","octa core","quad core","triple core","penta core","single core","octa core","triple core","dual core","single core","penta core","penta core","hepta core","quad core","octa core","hepta core","hexa core","penta core","hepta core","hepta core","dual core","quad core","penta core","dual core","dual core","penta core","octa core","quad core","single core","hepta core","quad core","hepta core","triple core","hexa core","hepta core"," ...

# %% [markdown]
# **Modelling**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
train_data=pd.read_csv('train.csv')

# %%
x = train_data.iloc[:, :-1].values
y = train_data.iloc[:, -1].values
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x = sc_x.fit_transform(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=0)

# %%
#logistic Regression
log=LogisticRegression()
log.fit(x_train,y_train)
print("Training score of LogisticRegression is: {}".format(log.score(x_train,y_train)*100))
y_predlog=log.predict(x_test)
print(y_predlog)
acrr=accuracy_score(y_test,y_predlog)*100
print("Accuracy of Logistic Regression Classifier is: {}%".format(acrr))
print("Confusion matrix Logistic Regression Classifier is: \n{}".format(confusion_matrix(y_test,y_predlog)))
print("{}".format(classification_report(y_test,y_predlog)))
# Out:
# Training score of LogisticRegression is: 97.93333333333332
# [3 0 2 2 3 0 0 3 3 1 1 3 0 2 3 0 3 2 2 1 0 0 3 1 2 2 3 1 3 1 1 0 2 0 1 3 0
#  0 3 3 3 1 3 3 1 3 0 1 3 1 1 3 0 3 0 2 2 2 0 3 3 1 3 2 1 2 3 2 2 2 3 2 1 0
#  1 3 2 2 1 2 3 3 3 0 0 0 2 1 2 3 1 2 2 1 0 3 3 3 0 3 1 1 2 1 3 2 2 3 2 3 3
#  0 0 1 3 3 0 0 1 0 0 3 2 2 1 2 1 1 0 2 1 3 3 3 3 3 3 2 0 1 1 2 1 3 0 3 0 0
#  2 0 1 1 1 1 3 0 0 3 1 3 2 1 3 1 2 3 3 2 1 0 3 1 2 3 3 0 2 2 3 1 2 1 0 1 2
#  1 2 0 3 3 1 1 0 2 3 0 1 2 2 0 3 3 3 1 2 3 3 3 0 0 0 2 3 3 0 0 1 3 2 3 3 3
#  0 0 2 3 3 1 0 2 0 0 0 3 2 1 2 2 1 1 0 2 3 3 0 0 1 3 3 1 3 0 3 1 1 0 2 3 3
#  2 0 0 1 2 3 2 2 3 1 1 0 3 3 2 1 3 2 2 2 1 0 2 2 1 0 0 2 2 2 3 0 1 3 0 2 2
#  3 0 2 0 1 1 3 0 0 2 3 1 2 0 2 0 3 0 3 3 2 3 1 2 2 1 1 2 0 1 0 3 1 0 3 0 0
#  1 3 0 3 1 1 0 1 3 0 2 1 1 2 1 1 0 2 0 0 3 1 2 3 2 2 0 3 2 2 1 3 2 3 3 3 0
#  2 0 3 0 1 1 2 3 1 3 1 2 0 1 2 3 0 0 1 3 0 3 0 2 2 1 1 0 2 0 0 1 3 0 3 3 0
#  2 1 3 1 1 3 2 0 3 2 2 0 0 3 0 1 1 1 3 2 3 2 0 3 0 0 1 3 0 0 3 2 2 2 3 0 0
#  1 2 1 2 0 3 3 0 3 3 0 2 2 1 0 2 2 1 3 2 2 0 2 0 3 3 2 1 0 3 1 2 0 0 1 3 0
#  3 0 0 1 2 0 1 3 0 3 2 1 2 0 3 0 2 3 2]
# Accuracy of Logistic Regression Classifier is: 96.2%
# Confusion matrix Logistic Regression Classifier is:
# [[122   2   0   0]
#  [  3 103   4   0]
#  [  0   5 116   4]
#  [  0   0   1 140]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       124
#            1       0.94      0.94      0.94       110
#            2       0.96      0.93      0.94       125
#            3       0.97      0.99      0.98       141
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %%
#Gussain NB
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
print("Training score of GaussianNB is {}".format(nb.score(x_train,y_train)*100))
y_pred=nb.predict(x_test)
ac_nb=accuracy_score(y_test,y_pred)*100
print("Accuracy of Naive Bayes Classifier is: {}".format(ac_nb))
print("Confusion matrix of Naive Bayes Classifier is:{}".format(confusion_matrix(y_test,y_pred)))
print("{}".format(classification_report(y_test,y_pred)))
# Out:
# Training score of GaussianNB is 81.39999999999999
# Accuracy of Naive Bayes Classifier is: 84.39999999999999
# Confusion matrix of Naive Bayes Classifier is:[[117   7   0   0]
#  [  6  83  21   0]
#  [  0  22  92  11]
#  [  0   0  11 130]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       124
#            1       0.74      0.75      0.75       110
#            2       0.74      0.74      0.74       125
#            3       0.92      0.92      0.92       141
#
#     accuracy                           0.84       500
#    macro avg       0.84      0.84      0.84       500
# weighted avg       0.84      0.84      0.84       500

# %%
#SVM
from sklearn.svm import SVC
svm=SVC(kernel='rbf')
svm.fit(x_train,y_train)
print("Training score of SVM is: {}".format(svm.score(x_train,y_train)*100))
y_pred_svm=svm.predict(x_test)
ac_svm=accuracy_score(y_test,y_pred_svm)*100
print("Accuracy of SVM is: {}".format(ac_svm))
print("Confusion matrix of SVM is: {}".format(confusion_matrix(y_test,y_pred_svm)))
print("{}".format(classification_report(y_test,y_pred_svm)))
# Out:
# Training score of SVM is: 98.06666666666666
# Accuracy of SVM is: 89.0
# Confusion matrix of SVM is: [[118   6   0   0]
#  [  6  96   8   0]
#  [  0  15 106   4]
#  [  0   0  16 125]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       124
#            1       0.82      0.87      0.85       110
#            2       0.82      0.85      0.83       125
#            3       0.97      0.89      0.93       141
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier(criterion = "entropy")
DT.fit(x_train,y_train)
print("Training score of DecisionTreeClassifier is: {}".format(DT.score(x_train,y_train)*100))
y_pred_DT=DT.predict(x_test)
ac_DT=accuracy_score(y_test,y_pred_DT)*100
print("Accuracy of Decision Tree Classifier is: {}".format(ac_DT))
print("Confusion matrix of Decision Tree Classifier is: {}".format(confusion_matrix(y_test,y_pred_DT)))
print("{}".format(classification_report(y_test,y_pred_DT)))
# Out:
# Training score of DecisionTreeClassifier is: 100.0
# Accuracy of Decision Tree Classifier is: 86.6
# Confusion matrix of Decision Tree Classifier is: [[112  12   0   0]
#  [  9  93   8   0]
#  [  0  12 102  11]
#  [  0   0  15 126]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       124
#            1       0.79      0.85      0.82       110
#            2       0.82      0.82      0.82       125
#            3       0.92      0.89      0.91       141
#
#     accuracy                           0.87       500
#    macro avg       0.86      0.86      0.86       500
# weighted avg       0.87      0.87      0.87       500

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier(n_estimators=300)
RF.fit(x_train,y_train)
print("Training score of Random Forest Classifier is: {}".format(RF.score(x_train,y_train)*100))
y_pred_RF=RF.predict(x_test)
ac_RF=accuracy_score(y_test,y_pred_RF)*100
print("Accuracy of Random Forest Classifier is: {}".format(ac_RF))
print("Confusion matrix of Random Forest Classifier is: {}".format(confusion_matrix(y_test,y_pred_RF)))
print("{}".format(classification_report(y_test,y_pred_RF)))
# Out:
# Training score of Random Forest Classifier is: 100.0
# Accuracy of Random Forest Classifier is: 87.6
# Confusion matrix of Random Forest Classifier is: [[121   3   0   0]
#  [  6  91  13   0]
#  [  0  21  93  11]
#  [  0   0   8 133]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       124
#            1       0.79      0.83      0.81       110
#            2       0.82      0.74      0.78       125
#            3       0.92      0.94      0.93       141
#
#     accuracy                           0.88       500
#    macro avg       0.87      0.87      0.87       500
# weighted avg       0.87      0.88      0.87       500

# %%
#Classifiers
classifiers=["LogisticRegression","GaussianNB","SVM","DecisionTreeClassifier","RandomForestClassifier"]
accuracy_=[acrr,ac_nb,ac_svm,ac_DT,ac_RF]
df_ac=pd.DataFrame({'model':classifiers,"accuracy":accuracy_})
px.histogram(data_frame=df_ac,x="model",y="accuracy")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ba7f127f-a6da-45e6-b8f6-43943a8fc21c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba7f127f-a6da-45e6-b8f6-43943a8fc21c")) {                    Plotly.newPlot(                        "ba7f127f-a6da-45e6-b8f6-43943a8fc21c",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"model=%{x}<br>sum of accuracy=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["LogisticRegression","GaussianNB","SVM","DecisionTreeClassifier","RandomForestClassifier"],"xaxis":"x","y":[96.2,84.39999999999999,89.0,86.6,87.6],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatter ...

# %%
data1 =train_data.loc[:,['battery_power','blue','dual_sim','fc','four_g','int_memory','m_dep','mobile_wt','n_cores','pc','px_height','px_width','ram','sc_h','sc_w','price_range']]
data1
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0               842     0         0   1       0           7    0.6        188
# 1              1021     1         1   0       1          53    0.7        136
# 2               563     1         1   2       1          41    0.9        145
# 3               615     1         0   0       0          10    0.8        131
# 4              1821     1         0  13       1          44    0.6        141
# ...             ...   ...       ...  ..     ...         ...    ...        ...
# 1995            794     1         1   0       1           2    0.8        106
# 1996           1965     1         1   0       0          39    0.2        187
# 1997           1911     0         1   1       1          36    0.7        108
# 1998           1512     0         0   4       1          46    0.1        145
# 1999            510     1         1   5       1          45    0.9        168
#
#       n_cores  pc  px_height  px_width   ram  sc_h  sc_w  price_range
# 0           2   2         20       756  2549     9     7            1
# 1           3   6        905      1988  2631    17     3            2
# 2           5   6       1263      1716  2603    11     2            2
# 3           6   9       1216      1786  2769    16     8            2
# 4           2  14       1208      1212  1411     8     2            1
# ...       ...  ..        ...       ...   ...   ...   ...          ...
# 1995        6  14       1222      1890   668    13     4            0
# 1996        4   3        915      1965  2032    11    10            2
# 1997        8   3        868      1632  3057     9     1            3
# 1998        5   5        336       670   869    18    10            0
# 1999        6  16        483       754  3919    19     4            3
#
# [2000 rows x 16 columns]

# %%
data2 = train_data.loc[:,['talk_time','three_g','wifi','touch_screen','clock_speed']]
data2
# Out:
#       talk_time  three_g  wifi  touch_screen  clock_speed
# 0            19        0     1             0          2.2
# 1             7        1     0             1          0.5
# 2             9        1     0             1          0.5
# 3            11        1     0             0          2.5
# 4            15        1     0             1          1.2
# ...         ...      ...   ...           ...          ...
# 1995         19        1     0             1          0.5
# 1996         16        1     1             1          2.6
# 1997          5        1     0             1          0.9
# 1998         19        1     1             1          0.9
# 1999          2        1     1             1          2.0
#
# [2000 rows x 5 columns]

# %% [markdown]
# **Merging datasets**

# %%
data3 = pd.concat([data1, data2], axis=1)
data3
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0               842     0         0   1       0           7    0.6        188
# 1              1021     1         1   0       1          53    0.7        136
# 2               563     1         1   2       1          41    0.9        145
# 3               615     1         0   0       0          10    0.8        131
# 4              1821     1         0  13       1          44    0.6        141
# ...             ...   ...       ...  ..     ...         ...    ...        ...
# 1995            794     1         1   0       1           2    0.8        106
# 1996           1965     1         1   0       0          39    0.2        187
# 1997           1911     0         1   1       1          36    0.7        108
# 1998           1512     0         0   4       1          46    0.1        145
# 1999            510     1         1   5       1          45    0.9        168
#
#       n_cores  pc  ...  px_width   ram  sc_h  sc_w  price_range  talk_time  \
# 0           2   2  ...       756  2549     9     7            1         19
# 1           3   6  ...      1988  2631    17     3            2          7
# 2           5   6  ...      1716  2603    11     2            2          9
# 3           6   9  ...      1786  2769    16     8            2         11
# 4           2  14  ...      1212  1411     8     2            1         15
# ...       ...  ..  ...       ...   ...   ...   ...          ...        ...
# 1995        6  14  ...      1890   668    13     4            0         19
# 1996        4   3  ...      1965  2032    11    10            2         16
# 1997        8   3  ...      1632  3057     9     1            3          5
# 1998        5   5  ...       670   869    18    10            0         19
# 1999        6  16  ...       754  3919    19     4            3          2
#
#       three_g  wifi  touch_screen  clock_speed
# 0           0     1             0          2.2
# 1           1     0             1          0.5
# 2           1     0             1          0.5
# 3           1     0             0          2.5
# 4           1     0             1          1.2
# ...       ...   ...           ...          ...
# 1995        1     0             1          0.5
# 1996        1     1             1          2.6
# 1997        1     0             1          0.9
# 1998        1     1             1          0.9
# 1999        1     1             1          2.0
#
# [2000 rows x 21 columns]

# %% [markdown]
# **Ranking datset according to price range**

# %%
dt = train_data
dt["rank_by_price"] = dt["price_range"].rank()
dt1 = dt
dt1.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...       756  2549     9     7         19        0
# 1        136        3  ...      1988  2631    17     3          7        1
# 2        145        5  ...      1716  2603    11     2          9        1
# 3        131        6  ...      1786  2769    16     8         11        1
# 4        141        2  ...      1212  1411     8     2         15        1
#
#    touch_screen  wifi  price_range  rank_by_price
# 0             0     1            1          750.5
# 1             1     0            2         1250.5
# 2             1     0            2         1250.5
# 3             0     0            2         1250.5
# 4             1     0            1          750.5
#
# [5 rows x 22 columns]

# %%
dt1['rank_by_price'].unique()
# Out:
# array([ 750.5, 1250.5, 1750.5,  250.5])

# %% [markdown]
# **Sorting the dataset according to ranked_price_range**

# %%
dt1.sort_values(by=["rank_by_price"])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1838            720     1          0.9         1  12       1          14
# 1762            808     1          0.5         1   3       0          46
# 419             914     1          0.9         0   2       0           4
# 846            1489     0          2.4         1   8       0          32
# 845            1907     0          2.0         0  13       0          55
# ...             ...   ...          ...       ...  ..     ...         ...
# 981            1046     1          2.8         1   0       1          58
# 982            1035     0          0.6         1   2       1          44
# 987            1688     0          2.5         0   0       1          21
# 956             862     0          2.3         0   9       1           6
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# 1838    0.8        165        4  ...      1234  1086    14     7          3
# 1762    0.5        105        8  ...       529  1082    15     5         10
# 419     0.8        100        2  ...      1495   808    11     7          5
# 846     0.6        200        1  ...       812   776     7     6          8
# 845     0.9        105        7  ...      1513   286    14     4         17
# ...     ...        ...      ...  ...       ...   ...   ...   ...        ...
# 981     0.2        100        8  ...      1040  3863    17    12          9
# 982     0.5         99        3  ...      1960  3506    14     5         12
# 987     0.2        170        7  ...       864  3984    17    14          8
# 956     0.1        107        8  ...      1977  3458     9     4          9
# 1999    0.9        168        6  ...       754  3919    19     4          2
#
#       three_g  touch_screen  wifi  price_range  rank_by_price
# 1838        1             1     0            0          250.5
# 1762        1             0     1            0          250.5
# 419         1             1     0            0          250.5
# 846         0             0     0            0          250.5
# 845         1             0     1            0          250.5
# ...       ...           ...   ...          ...            ...
# 981         1             1     1            3         1750.5
# 982         1             1     0            3         1750.5
# 987         1             1     1            3         1750.5
# 956         1             1     1            3         1750.5
# 1999        1             1     1            3         1750.5
#
# [2000 rows x 22 columns]

# %% [markdown]
# **Ranking on all the features using rank()**

# %%
dt2 = train_data
RankedDataset1 = dt2.rank()
RankedDataset1.sort_values(by="price_range")
# Out:
#       battery_power    blue  clock_speed  dual_sim      fc  four_g  \
# 1838          320.5  1505.5        638.5    1491.0  1853.0  1479.0
# 1762          435.5  1505.5        207.0    1491.0   993.5   479.0
# 419           589.0  1505.5        638.5     491.0   814.0   479.0
# 846          1323.5   505.5       1612.5    1491.0  1601.0   479.0
# 845          1875.0   505.5       1337.0     491.0  1895.5   479.0
# ...             ...     ...          ...       ...     ...     ...
# 981           753.0  1505.5       1868.0    1491.0   237.5  1479.0
# 982           737.5   505.5        450.5    1491.0   814.0  1479.0
# 987          1583.0   505.5       1678.5     491.0   237.5  1479.0
# 956           515.5   505.5       1544.5     491.0  1678.5  1479.0
# 1999           21.0  1505.5       1337.0    1491.0  1281.0  1479.0
#
#       int_memory   m_dep  mobile_wt  n_cores  ...  px_width     ram    sc_h  \
# 1838       432.0  1595.5     1414.5    872.5  ...     978.0   445.5  1214.0
# 1762      1451.5  1003.0      436.0   1872.5  ...      45.0   442.0  1353.0
# 419         77.5  1595.5      325.5    366.0  ...    1341.0   306.0   791.5
# 846       1011.0  1198.5     1991.0    121.5  ...     408.0   292.0   287.0
# 845       1727.0  1797.0      436.0   1615.0  ...    1363.0    16.0  1214.0
# ...          ...     ...        ...      ...  ...       ...     ...     ...
# 981       1828.5   427.0      325.5   1872.5  ...     728.0  1919.0  1660.0
# 982       1382.0  1003.0      309.0    612.5  ...    1937.0  1732.0  1214.0
# 987        669.5   427.0     1496.0   1615.0  ...     481.5  1994.0  1660.0
# 956        142.0   160.5      472.5   1872.5  ...    1966.0  1703.5   541.5
# 1999      1418.0  1797.0     1457.5   1370.5  ...     331.5  1959.0  1938.5
#
#         sc_w  talk_time  three_g  touch_screen    wifi  price_range  \
# 1838  1284.5      146.5   1239.0        1497.5   493.5        250.5
# 1762  1008.0      901.0   1239.0         497.5  1493.5        250.5
# 419   1284.5      363.0   1239.0        1497.5   493.5        250.5
# 846   1153.5      696.5    239.0         497.5   493.5        250.5
# 845    836.5     1636.5   1239.0         497.5  1493.5        250.5
# ...      ...        ...      ...           ...     ...          ...
# 981   1797.5      798.5   1239.0        1497.5  1493.5       1750.5
# 982   1008.0     1106.0   1239.0        1497.5   493.5       1750.5
# 987   1897.0      696.5   1239.0        1497.5  1493.5       1750.5
# 956    836.5      798.5   1239.0        1497.5  1493.5       1750.5
# 1999   836.5       50.0   1239.0        1497.5  1493.5       1750.5
#
#       rank_by_price
# 1838          250.5
# 1762          250.5
# 419           250.5
# 846           250.5
# 845           250.5
# ...             ...
# 981          1750.5
# 982          1750.5
# 987          1750.5
# 956          1750.5
# 1999         1750.5
#
# [2000 rows x 22 columns]

# %% [markdown]
# **Rankig all the features seperately to correct output**

# %%
# because not all features are good when values are high and not all features are good when values are low
# It depends on each and every feature

b = dt2
b["rank_by_price"] = b["price_range"].rank()
b["rank_by_battery"] = b["battery_power"].rank(ascending=False)
b["rank_by_blueooth"] = b["blue"].rank(ascending=False)
b["rank_by_clockspeed"] = b["clock_speed"].rank(ascending=False)
b["rank_by_DualSIM"] = b["dual_sim"].rank(ascending=False)
b["rank_by_fc"] = b["fc"].rank(ascending=False)
b["rank_by_4G"] = b["four_g"].rank(ascending=False)
b["rank_by_InternalMemory"] = b["int_memory"].rank(ascending=False)
b["rank_by_mdep"] = b["m_dep"].rank(ascending=False)
b["rank_by_weight"] = b["mobile_wt"].rank(ascending=True)
b["rank_by_ncores"] = b["n_cores"].rank(ascending=False)
b["rank_by_pc"] = b["pc"].rank(ascending=False)
b["rank_by_height"] = b["px_height"].rank(ascending=False)
b["rank_by_width"] = b["px_width"].rank(ascending=False)
b["rank_by_ram"] = b["ram"].rank(ascending=False)
b["rank_by_sch"] = b["sc_h"].rank(ascending=False)
b["rank_by_scw"] = b["sc_w"].rank(ascending=False)
b["rank_by_talktime"] = b["talk_time"].rank(ascending=False)
b["rank_by_3G"] = b["three_g"].rank(ascending=False)
b["rank_by_touchscreen"] = b["touch_screen"].rank(ascending=False)
b["rank_by_wifi"] = b["wifi"].rank(ascending=False)
b.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  rank_by_pc  rank_by_height  rank_by_width  \
# 0        188        2  ...      1746.0          1972.5         1664.5
# 1        136        3  ...      1402.0           545.5           17.0
# 2        145        5  ...      1402.0           212.0          386.5
# 3        131        6  ...      1090.5           250.0          287.0
# 4        141        2  ...       606.5           261.5         1054.0
#
#    rank_by_ram  rank_by_sch  rank_by_scw  rank_by_talktime  rank_by_3G  \
# 0        762.5       1459.5        716.5             159.0      1762.0
# 1        714.0        341.0       1355.0            1418.5       762.0
# 2        732.0       1209.5       1532.5            1202.5       762.0
# 3        639.0        509.0        588.0             996.0       762.0
# 4       1375.0       1580.0       1532.5             587.0       762.0
#
#    rank_by_touchscreen  rank_by_wifi
# 0               1503.5         507.5
# 1                503.5        1507.5
# 2                503.5        1507.5
# 3               1503.5        1507.5
# 4                503.5        1507.5
#
# [5 rows x 42 columns]
